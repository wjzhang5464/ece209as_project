# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os 
os.chdir('/content/drive/MyDrive/209AS/deepfake/final/')   #replace with your notebook path

# %%
# !pip install torch===1.4.0
# !pip install torchvision===0.5.0
# !pip install numpy>=1.18.1
# !pip install scipy>=1.2.1
# !pip install scenedetect==0.5.1
# !pip install opencv-contrib-python
# !pip install python_speech_features
# !pip install tensorboardX

# %% [markdown]
# ## Train original model:

# %%
# !python Multimodal_Detection/train_ori.py --train 1 --epochs 50 --batch_size 8 --out_dir './Multimodal_Detection/dataset/DFDC/' --loss 2  #start training on DFDC dataset
#loss 1: L1; loss 2: L1+L2; loss 3: L1+L2+L3

# %%
# !python Multimodal_Detection/train_ori.py --train 1 --resume 'your pth.tar path'--epochs 50 --batch_size 8 --out_dir './Multimodal_Detection/' # if you want to resume the training then run this

# %% [markdown]
# ## Train model with lstm:

# %%
# !python Multimodal_Detection/train_lstm.py --train 1 --epochs 50 --img_dim 96 --batch_size 8 --out_dir './Multimodal_Detection/dataset/DFDC/' --loss 2 #start training on DFDC dataset it may take a while at first
#loss 2: L1+L2; loss 3: L1+L2+L3

# %%
#!python Multimodal_Detection/train_lstm.py --train 1 --resume 'your pth.tar path' --img_dim 96 --epochs 75 --batch_size 8 --out_dir './Multimodal_Detection/' # if you want to resume the training then run this
